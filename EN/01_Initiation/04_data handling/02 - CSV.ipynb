# %%
import csv

# %% [markdown]
# Content of the CSV file *exemple.csv* :
#
#     nom,role
#     Joe Satriani,Guitariste
#     Stu Hamm,Bassiste
#     Jeff Capitelli,Batteur
#
# Content of the CSV file *exemple2.csv* :
#
#     "nom";"role"
#     "Joe Satriani";"Guitariste"
#     "Stu Hamm";"Bassiste"
#     "Jeff Capitelli";"Batteur"
#
# The CSV file can use differents dialects. That is why it is necessary to detect this dialect before reading data.
#
# So, reading a CSV file is a two step process:

# %%
with open("exemple.csv") as f:
    dialect = csv.Sniffer().sniff(f.readline())
    # f.seek(0)
    reader = csv.reader(f, dialect=dialect)
    data = list(reader)

# %% [markdown]
# We got a list og list (2 dimension table)

# %%
data
# Out:
# [['Joe Satriani', 'Guitariste'],
#  ['Stu Hamm', 'Bassiste'],
#  ['Jeff Capitelli', 'Batteur']]

# %%
dir(dialect)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_name',
#  '_valid',
#  '_validate',
#  'delimiter',
#  'doublequote',
#  'escapechar',
#  'lineterminator',
#  'quotechar',
#  'quoting',
#  'skipinitialspace']

# %% [markdown]
# Here are the details of dialect properties:

# %%
print('delimiter:', dialect.delimiter)
print('doublequote:', dialect.doublequote)
print('escapechar:', dialect.escapechar)
print('lineterminator:', repr(dialect.lineterminator))
print('quotechar:', dialect.quotechar)
print('quoting:', dialect.quoting)
print('skipinitialspace:', dialect.skipinitialspace)
# Out:
# delimiter: ,
# doublequote: False
# escapechar: None
# lineterminator: '\r\n'
# quotechar: "
# quoting: 0
# skipinitialspace: False

# %%
csv.QUOTE_MINIMAL, csv.QUOTE_ALL, csv.QUOTE_NONNUMERIC, csv.QUOTE_NONE
# Out:
# (0, 1, 2, 3)

# %%
with open("exemple2.csv") as f:
    dialect = csv.Sniffer().sniff(f.readline())
    # f.seek(0)
    reader = csv.reader(f, dialect=dialect)
    data = list(reader)

# %%
print('delimiter:', dialect.delimiter)
print('doublequote:', dialect.doublequote)
print('escapechar:', dialect.escapechar)
print('lineterminator:', repr(dialect.lineterminator))
print('quotechar:', dialect.quotechar)
print('quoting:', dialect.quoting)
print('skipinitialspace:', dialect.skipinitialspace)
# Out:
# delimiter: ;
# doublequote: False
# escapechar: None
# lineterminator: '\r\n'
# quotechar: "
# quoting: 0
# skipinitialspace: False

# %% [markdown]
# **Dialecte Unix**

# %%
print('delimiter:', csv.unix_dialect.delimiter)
print('doublequote:', csv.unix_dialect.doublequote)
print('escapechar:', csv.unix_dialect.escapechar)
print('lineterminator:', repr(csv.unix_dialect.lineterminator))
print('quotechar:', csv.unix_dialect.quotechar)
print('quoting:', csv.unix_dialect.quoting)
print('skipinitialspace:', csv.unix_dialect.skipinitialspace)
# Out:
# delimiter: ,
# doublequote: True
# escapechar: None
# lineterminator: '\n'
# quotechar: "
# quoting: 1
# skipinitialspace: False

# %% [markdown]
# **Dialecte Excel**

# %%
print('delimiter:', csv.excel.delimiter)
print('doublequote:', csv.excel.doublequote)
print('escapechar:', csv.excel.escapechar)
print('lineterminator:', repr(csv.excel.lineterminator))
print('quotechar:', csv.excel.quotechar)
print('quoting:', csv.excel.quoting)
print('skipinitialspace:', csv.excel.skipinitialspace)
# Out:
# delimiter: ,
# doublequote: True
# escapechar: None
# lineterminator: '\r\n'
# quotechar: "
# quoting: 0
# skipinitialspace: False

# %% [markdown]
# **Dialecte Excel avec tabulations**

# %%
print('delimiter:', repr(csv.excel_tab.delimiter))
print('doublequote:', csv.excel_tab.doublequote)
print('escapechar:', csv.excel_tab.escapechar)
print('lineterminator:', repr(csv.excel_tab.lineterminator))
print('quotechar:', csv.excel_tab.quotechar)
print('quoting:', csv.excel_tab.quoting)
print('skipinitialspace:', csv.excel_tab.skipinitialspace)
# Out:
# delimiter: '\t'
# doublequote: True
# escapechar: None
# lineterminator: '\r\n'
# quotechar: "
# quoting: 0
# skipinitialspace: False

# %% [markdown]
# Improving data readability
# --

# %%
with open("exemple.csv") as f:
    dialect = csv.Sniffer().sniff(f.read())
    f.seek(0)
    reader = csv.DictReader(f, dialect=dialect)
    data = list(reader)

# %%
data
# Out:
# [{'nom': 'Joe Satriani', 'role': 'Guitariste'},
#  {'nom': 'Stu Hamm', 'role': 'Bassiste'},
#  {'nom': 'Jeff Capitelli', 'role': 'Batteur'}]

# %%
dir(csv)

# %% [markdown]
# Writing a CSV file
# ------------------

# %%
for d in data:
    d["Modifié"] = True

# %%
data  # .sort(key=operator.itemgetter("role"))
# Out:
# [{'nom': 'Joe Satriani', 'role': 'Guitariste', 'Modifié': True},
#  {'nom': 'Stu Hamm', 'role': 'Bassiste', 'Modifié': True},
#  {'nom': 'Jeff Capitelli', 'role': 'Batteur', 'Modifié': True}]

# %%
with open("exemple_writed.csv", "w") as f:
    writer = csv.DictWriter(f, dialect=csv.unix_dialect, fieldnames=[])
    print(dir(writer))
    # writer.writerows(data)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_dict_to_list', 'extrasaction', 'fieldnames', 'restval', 'writeheader', 'writer', 'writerow', 'writerows']

# %%
with open("exemple_writed.csv", "w") as f:
    writer = csv.DictWriter(f, dialect=csv.unix_dialect, fieldnames=["Modifié", "nom", "role"])
    writer.writerows(data)

with open("exemple_writed.csv") as f:
    print(f.read())
# Out:
# "True","Joe Satriani","Guitariste"
# "True","Stu Hamm","Bassiste"
# "True","Jeff Capitelli","Batteur"

# %%
with open("exemple_writed.csv", "w") as f:
    writer = csv.DictWriter(f, dialect=csv.unix_dialect, fieldnames=["Modifié", "nom", "role"])
    writer.writeheader()
    writer.writerows(data)

with open("exemple_writed.csv") as f:
    print(f.read())
# Out:
# "Modifié","nom","role"
# "True","Joe Satriani","Guitariste"
# "True","Stu Hamm","Bassiste"
# "True","Jeff Capitelli","Batteur"

# %%
for d in data[::2]:
    d["pair"] = True

print(data)
# Out:
# [{'nom': 'Joe Satriani', 'role': 'Guitariste', 'Modifié': True, 'pair': True}, {'nom': 'Stu Hamm', 'role': 'Bassiste', 'Modifié': True}, {'nom': 'Jeff Capitelli', 'role': 'Batteur', 'Modifié': True, 'pair': True}]

# %%
with open("exemple_writed.csv", "w") as f:
    writer = csv.DictWriter(f, dialect=csv.unix_dialect, fieldnames=["pair", "nom", "role"])
    writer.writeheader()
    writer.writerows(data)

with open("exemple_writed.csv") as f:
    print(f.read())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 4
#       2     writer = csv.DictWriter(f, dialect=csv.unix_dialect, fieldnames=["pair", "nom", "role"])
#       3     writer.writeheader()
# ----> 4     writer.writerows(data)
#       6 with open("exemple_writed.csv") as f:
#       7     print(f.read())
#
# File /usr/lib/python3.11/csv.py:157, in DictWriter.writerows(self, rowdicts)
#     156 def writerows(self, rowdicts):
# --> 157     return self.writer.writerows(map(self._dict_to_list, rowdicts))
#
# File /usr/lib/python3.11/csv.py:149, in DictWriter._dict_to_list(self, rowdict)
#     147     wrong_fields = rowdict.keys() - self.fieldnames
#     148     if wrong_fields:
# --> 149         raise ValueError("dict contains fields not in fieldnames: "
#     150                          + ", ".join([repr(x) for x in wrong_fields]))
#     151 return (rowdict.get(key, self.restval) for key in self.fieldnames)
#
# ValueError: dict contains fields not in fieldnames: 'Modifié'

# %%
with open("exemple_writed.csv", "w") as f:
    writer = csv.DictWriter(f, dialect=csv.unix_dialect, fieldnames=["pair", "nom", "role"], extrasaction="ignore")
    writer.writeheader()
    writer.writerows(data)

with open("exemple_writed.csv") as f:
    print(f.read())
# Out:
# "pair","nom","role"
# "True","Joe Satriani","Guitariste"
# "","Stu Hamm","Bassiste"
# "True","Jeff Capitelli","Batteur"

# %%
help(csv.DictWriter)

# %%
with open("exemple_writed.csv", "w") as f:
    writer = csv.DictWriter(f, dialect=csv.unix_dialect, fieldnames=["pair", "nom", "role"], extrasaction="ignore", restval="False")
    writer.writeheader()
    writer.writerows(data)

with open("exemple_writed.csv") as f:
    print(f.read())
# Out:
# "pair","nom","role"
# "True","Joe Satriani","Guitariste"
# "False","Stu Hamm","Bassiste"
# "True","Jeff Capitelli","Batteur"

# %%
print(data)
# Out:
# [{'nom': 'Joe Satriani', 'role': 'Guitariste', 'Modifié': True, 'pair': True}, {'nom': 'Stu Hamm', 'role': 'Bassiste', 'Modifié': True}, {'nom': 'Jeff Capitelli', 'role': 'Batteur', 'Modifié': True, 'pair': True}]

# %% [markdown]
# ---

# %%
with open("exemple_writed.csv", "w") as f:
    writer = csv.writer(f, dialect=csv.unix_dialect)
    writer.writerow(["nom", "role", "Modifié", "pair"])
    writer.writerows(d.values() for d in data)

with open("exemple_writed.csv") as f:
    print(f.read())
# Out:
# "nom","role","Modifié","pair"
# "Joe Satriani","Guitariste","True","True"
# "Stu Hamm","Bassiste","True"
# "Jeff Capitelli","Batteur","True","True"

# %%
data

# %% [markdown]
# ---
