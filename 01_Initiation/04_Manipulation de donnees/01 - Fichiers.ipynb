# %% [markdown]
# Gestion des fichiers
# --
#
# La plupart des systèmes de fichiers modernes sont en unicode et les fichiers textuels générés sont encodés en unicode. Mais on croise souvent des fichiers textuels encodés différemment.

# %%
with open("fichier_unicode.txt") as f:
    content = f.read()
print(content)
print(type(content))
# Out:
# Ceci est un fichier.
# Il contient deux caractères accentués.
#
# <class 'str'>

# %%
with open("fichier_unicode.txt", encoding="utf-8") as f:
    content = f.read()
print(content)
print(type(content))
# Out:
# Ceci est un fichier.
# Il contient deux caractères accentués.
#
# <class 'str'>

# %%
with open("fichier_latin1.txt") as f:
    content = f.read()
print(content)
print(type(content))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[3], line 2
#       1 with open("fichier_latin1.txt") as f:
# ----> 2     content = f.read()
#       3 print(content)
#       4 print(type(content))
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 7: invalid continuation byte

# %%
with open("fichier_latin1.txt", encoding="latin1") as f:
    content = f.read()
print(content)
print(type(content))
# Out:
# accentué.
#
# <class 'str'>

# %%
with open("fichier_latin1.txt", encoding="iso-8859-15") as f:
    content = f.read()
print(content)
print(type(content))

# %% [markdown]
# Ouverture d'un fichier binaire
# --

# %%
with open("fichier_latin1.txt", "rb") as f:
    content = f.read()
print(content)
print(type(content))
# Out:
# b'accentu\xe9.\n'
# <class 'bytes'>

# %%
# You should execute this line to install chardet
import subprocess
print(subprocess.getstatusoutput("pip install chardet"))
# Out:
# (0, 'Collecting chardet\n  Downloading chardet-5.2.0-py3-none-any.whl (199 kB)\n\x1b[?25l     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/199.4 kB\x1b \x1b?\x1b eta \x1b-:--:--\x1b\n\x1b[2K     \x1b━━━━━━━━\x1b\x1b╺\x1b\x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b41.0/199.4 kB\x1b \x1b3.7 MB/s\x1b eta \x1b0:00:01\x1b\n\x1b[2K     \x1b━━━━━━━━\x1b\x1b╺\x1b\x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b41.0/199.4 kB\x1b \x1b3.7 MB/s\x1b eta \x1b0:00:01\x1b\n\x1b[2K     \x1b━━━━━━━━\x1b\x1b╺\x1b\x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b41.0/199.4 kB\x1b \x1b3.7 MB/s\x1b eta \x1b0:00:01\x1b\n\x1b[2K     \x1b━━━━━━━━\x1b\x1b╺\x1b\x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b41.0/199.4 kB\x1b \x1b3.7 MB/s\x1b eta \x1b0:00:01\x1b\n\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━\x1b\x1b╺\x1b\x1b━━━━━━━━━━━━━━━━━\x1b \x1b102.4/199.4 kB\x1b \x1b596.9 kB/s\x1b eta \x1b0:00:01\x1b\n\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━\x1b\x1b╺\x1b\x1b━━━━━━━━━━━━━━━━━\x1b \x1b102.4/199.4 kB\x1b \x1b596.9 kB/s\x1b eta \x1b0:00:01\x1b\n\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b199.4/199.4 kB\x1b \x1b846.3 kB/s\x1b eta \x1b0:00:00\x1b\n\x1b[?25hInstalling collected packages: chardet\nSuccessfully installed chardet-5.2.0')

# %%
import chardet
with open("fichier_latin1.txt", "rb") as f:
    print(chardet.detect(f.read()))
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %% [markdown]
# Ouverture d'un fichier en détectant son encodage
# --

# %%
import chardet
with open("fichier_latin1.txt", "rb") as f:
    detected_encoding = chardet.detect(f.read())

with open("fichier_latin1.txt", encoding=detected_encoding["encoding"]) as f:
    content = f.read()
    print(content)
    print(type(content))
# Out:
# accentué.
#
# <class 'str'>

# %% [markdown]
# Ecriture dans un fichier
# --

# %%
with open("test.txt", "w") as f:
    position = f.write("Truc.")
    print(position)

with open("test.txt", "r") as f:
    assert f.read() == "Truc.", "Le contenu n'est pas conforme."

# %%
with open("test.txt", "a") as f:
    print(f.tell())
    content = f.write("Chose.")

with open("test.txt", "r") as f:
    assert f.read() == "Truc.Chose."

# %%
print(content)

# %%
with open("multi.txt", "w") as f:
    f.write("Ceci\nest\nun\nfichier\nmultilignes.")

with open("multi.txt") as f:
    print(repr(f.read()))

# %%
with open("multi.txt") as f:
    print(f.readlines())

# %%
with open("multi.txt") as f:
    for i, line in enumerate(f.readlines()):
        print("ligne", i, ":", repr(line))

# %%
with open("multi.txt") as f:
    for i, line in enumerate(f.readlines()):
        print("ligne", i, ":", line.strip())

# %%
with open("multi.txt") as f:
    i = 0
    while True:
        line = f.readline()
        print("ligne", i, ":", line.strip(), "|", f.tell())
        if not line:
            break
        i += 1
# Out:
# ligne 0 : Ceci | 5
# ligne 1 : était | 12
# ligne 2 : un | 15
# ligne 3 : beau | 20
# ligne 4 : fichier | 28
# ligne 5 : multilignes. | 40
# ligne 6 :  | 40

# %%
with open("test.txt", "r+") as f:
    print(f.tell())
    print(f.read())
    print(f.tell())
    f.seek(4)
    f.write("-c")

with open("test.txt", "r") as f:
    assert f.read() == "Truc-chose.", "Erreur dans la démo"
    print("Ce qui s'est passé est ce qui était prévu")

# %%
with open("test.txt", "r") as f:
    content = f.read()

content = content[:5].lower() + "bidule-" + content[5:]

with open("test.txt", "w") as f:
    f.write(content)

with open("test.txt", "r") as f:
    print(f.read())

# %%
from os.path import exists
if not exists("existe_pas.txt"):
    print("Création du fichier")
    with open("existe_pas.txt", "w") as f:
        pass
else:
    print("fichier déjà créé")

# %%
with open("multi.txt", "r") as f:
    content = f.readlines()

print(content)
content.insert(3, "beau\n")
content[1] = "était\n"
print(content)

with open("multi.txt", "w") as f:
    f.writelines(content)

with open("multi.txt", "r") as f:
    print(f.read())

# %% [markdown]
# ---
