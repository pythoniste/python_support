# %%
# You should execute this line to install pygal, cairosvg and bottle
import subprocess
print(subprocess.getstatusoutput("pip install pygal"))
print(subprocess.getstatusoutput("pip install cairosvg"))
print(subprocess.getstatusoutput("pip install bottle"))
# Out:
# (0, 'Requirement already satisfied: pygal in ./.venv/lib/python3.11/site-packages (3.0.5)\nRequirement already satisfied: importlib-metadata in ./.venv/lib/python3.11/site-packages (from pygal) (8.7.0)\nRequirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.11/site-packages (from importlib-metadata->pygal) (3.22.0)')
# ...

# %%
import pygal

graph = pygal.Line()
graph.title = '% Change Coolness of programming languages over time.'
graph.x_labels = ['2011','2012','2013','2014','2015','2016']
graph.add('Python',  [15, 31, 89, 200, 356, 900])
graph.add('Java',    [15, 45, 76, 80,  91,  95])
graph.add('C++',     [5,  51, 54, 102, 150, 201])
graph.add('All others combined!',  [5, 15, 21, 55, 92, 105])

# %%
graph.render_to_file('lines.svg')

# %%
import pygal

bar_chart = pygal.Bar()
bar_chart.add('Category A', [1, 3, 5, 7])
bar_chart.add('Category B', [2, 4, 6, 8])

# %%
import pygal

line_chart = pygal.Line()
line_chart.add('Series 1', [1, 3, 5, 7])
line_chart.add('Series 2', [2, 4, 6, 8])

# %%
import pygal

pie_chart = pygal.Pie()
pie_chart.add('Part A', 10)
pie_chart.add('Part B', 20)
pie_chart.add('Part C', 30)

# %%
pie_chart = pygal.Pie(inner_radius=0.4)
pie_chart.add('Part A', 10)
pie_chart.add('Part B', 20)
pie_chart.add('Part C', 30)

# %%
radar_chart = pygal.Radar()
radar_chart.add('Series 1', [1, 2, 3, 4])
radar_chart.add('Series 2', [4, 3, 2, 1])

# %%
bar_chart = pygal.Bar(title='Bar Chart Title', x_label_rotation=30)
bar_chart.add('Category A', [1, 3, 5, 7])
bar_chart.add('Category B', [2, 4, 6, 8])

# %%
from pygal.style import Style

custom_style = Style(
    colors=['#E80080', '#404040'],
    background='#FFFFFF',
    plot_background='#EFEFEF',
    opacity='.6',
    label_font_size=14,
)

bar_chart = pygal.Bar(style=custom_style)
bar_chart.add('Category A', [1, 3, 5, 7])
bar_chart.add('Category B', [2, 4, 6, 8])

# %%
data = {'Expected': [100, 102, 105], 'Delivered': [76, 100, 101]}
bar_chart = pygal.Bar()
bar_chart.title = "Efficiency"
bar_chart.x_labels = map(str, range(2019, 2022))
for key, values in data.items():
    bar_chart.add(key, values)
bar_chart

# %%
{('2022', 'Arc de Triomphe'): 1754750,
 ('2019', 'Arc de Triomphe'): 1606710,
 ('2019', 'Abbaye du Mont-Saint-Michel'): 1479290,
 ('2019', 'Sainte-Chapelle du Palais'): 1375610,
 ('2022', 'Abbaye du Mont-Saint-Michel'): 1285610,
 ('2022', 'Sainte-Chapelle du Palais'): 1201620,
 ('2019', 'Domaine national de Chambord'): 1130850,
 ('2022', 'Domaine national de Chambord'): 1053950,
 ('2022', 'Panthéon'): 949760,
 ('2019', 'Panthéon'): 875670}
