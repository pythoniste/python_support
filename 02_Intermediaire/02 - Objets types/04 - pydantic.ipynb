# %% [markdown]
# Pydantic
# ==
#
# La sémantique du module `pydantic` est similaire à celle du module `dataclasses`, ajoutant la **validation des données** et le **forçage des types**.
#
# **L'intérêt principal de `pydantic` est qu'il permet de valider efficacement les données.**
#
# Ce module s'installe ainsi:

# %%
# You should execute this line to install pydantic
import subprocess
print(subprocess.getstatusoutput("pip install pydantic==2.11.5 bottle flask chardet"))
# Out:
# (0, 'Requirement already satisfied: pydantic==2.11.5 in /home/sch-bm/Documents/repositories/python_support/.venv/lib/python3.11/site-packages (2.11.5)\nRequirement already satisfied: bottle in /home/sch-bm/Documents/repositories/python_support/.venv/lib/python3.11/site-packages (0.13.3)\nRequirement already satisfied: flask in /home/sch-bm/Documents/repositories/python_support/.venv/lib/python3.11/site-packages (3.1.1)\nRequirement already satisfied: chardet in /home/sch-bm/Documents/repositories/python_support/.venv/lib/python3.11/site-packages (5.2.0)\nRequirement already satisfied: annotated-types>=0.6.0 in /home/sch-bm/Documents/repositories/python_support/.venv/lib/python3.11/site-packages (from pydantic==2.11.5) (0.7.0)\nRequirement already satisfied: pydantic-core==2.33.2 in /home/sch-bm/Documents/repositories/python_support/.venv/lib/python3.11/site-packages (from pydantic==2.11.5) (2.33.2)\nRequirement already satisfied: typing-extensions>=4.12.2 in /home/sch-bm/Documents/repositories/python_support/.venv/lib/python3.11/site-packages (from pydantic==2.11.5) (4.13.2)\nRequirement already satisfied: typing-inspection>=0.4.0 in /home/sch-bm/Documents/repositories/python_support/.venv/lib/python3.11/site-packages (from pydantic==2.11.5) (0.4.1)\nRequirement already satisfied: blinker>=1.9.0 in /home/sch-bm/Documents/repositories/python_support/.venv/lib/python3.11/site-packages (from flask) (1.9.0)\nRequirement already satisfied: click>=8.1.3 in /home/sch-bm/Documents/repositories/python_support/.venv/lib/python3.11/site-packages (from flask) (8.2.1)\nRequirement already satisfied: itsdangerous>=2.2.0 in /home/sch-bm/Documents/repositories/python_support/.venv/lib/python3.11/site-packages (from flask) (2.2.0)\nRequirement already satisfied: jinja2>=3.1.2 in /home/sch-bm/Documents/repositories/python_support/.venv/lib/python3.11/site-packages (from flask) (3.1.6)\nRequirement already satisfied: markupsafe>=2.1.1 in /home/sch-bm/Documents/repositories/python_support/.venv/lib/python3.11/site-packages (from flask) (3.0.2)\nRequirement already satisfied: werkzeug>=3.1.0 in /home/sch-bm/Documents/repositories/python_support/.venv/lib/python3.11/site-packages (from flask) (3.1.3)')

# %%
from pydantic import BaseModel

# %%
class Livre(BaseModel):
    auteur: str
    titre: str
    nb_pages: int | None = None

# %%
livre = Livre(
    auteur = "Sébastien CHAZALLET",
    titre = "Python3, les fondamentaux du langage",
    nb_pages = 702,
)

# %%
livre
# Out:
# Livre(auteur='Sébastien CHAZALLET', titre='Python3, les fondamentaux du langage', nb_pages=702)

# %%
print(livre)
# Out:
# auteur='Sébastien CHAZALLET' titre='Python3, les fondamentaux du langage' nb_pages=702

# %%
livre.model_dump()
# Out:
# {'auteur': 'Sébastien CHAZALLET',
#  'titre': 'Python3, les fondamentaux du langage',
#  'nb_pages': 702}

# %%
from pprint import pprint
pprint(Livre.model_json_schema())
# Out:
# {'properties': {'auteur': {'title': 'Auteur', 'type': 'string'},
#                 'nb_pages': {'anyOf': [{'type': 'integer'}, {'type': 'null'}],
#                              'default': None,
#                              'title': 'Nb Pages'},
#                 'titre': {'title': 'Titre', 'type': 'string'}},
#  'required': ['auteur', 'titre'],
#  'title': 'Livre',
#  'type': 'object'}

# %%
Livre(
    "Sébastien CHAZALLET",
    "Python3, les fondamentaux du langage",
    702,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 Livre(
#       2     "Sébastien CHAZALLET",
#       3     "Python3, les fondamentaux du langage",
#       4     702,
#       5 )
#
# TypeError: BaseModel.__init__() takes 1 positional argument but 4 were given

# %%
Livre(
    auteur="Sébastien CHAZALLET",
    titre="Python3, les fondamentaux du langage",
)
# Out:
# Livre(auteur='Sébastien CHAZALLET', titre='Python3, les fondamentaux du langage', nb_pages=None)

# %%
livre.editeur = "ENI"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 livre.editeur = "ENI"
#
# File ~/Documents/repositories/python_support/.venv/lib/python3.11/site-packages/pydantic/main.py:997, in BaseModel.__setattr__(self, name, value)
#     995     setattr_handler(self, name, value)
#     996 # if None is returned from _setattr_handler, the attribute was set directly
# --> 997 elif (setattr_handler := self._setattr_handler(name, value)) is not None:
#     998     setattr_handler(self, name, value)  # call here to not memo on possibly unknown fields
#     999     self.__pydantic_setattr_handlers__[name] = setattr_handler
#
# File ~/Documents/repositories/python_support/.venv/lib/python3.11/site-packages/pydantic/main.py:1044, in BaseModel._setattr_handler(self, name, value)
#    1041 elif name not in cls.__pydantic_fields__:
#    1042     if cls.model_config.get('extra') != 'allow':
#    1043         # TODO - matching error
# -> 1044         raise ValueError(f'"{cls.__name__}" object has no field "{name}"')
#    1045     elif attr is None:
#    1046         # attribute does not exist, so put it in extra
#    1047         self.__pydantic_extra__[name] = value
#
# ValueError: "Livre" object has no field "editeur"

# %%
Livre(
    auteur=42,
    titre="Python3, les fondamentaux du langage",
    nb_pages=702,
    editeur="ENI",
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 Livre(
#       2     auteur=42,
#       3     titre="Python3, les fondamentaux du langage",
#       4     nb_pages=702,
#       5     editeur="ENI",
#       6 )
#
# File ~/Documents/repositories/python_support/.venv/lib/python3.11/site-packages/pydantic/main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
#     257         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     258         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     259         stacklevel=2,
#     260     )
#
# ValidationError: 1 validation error for Livre
# auteur
#   Input should be a valid string [type=string_type, input_value=42, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type

# %%
livre = Livre(
    auteur = "Sébastien CHAZALLET",
    nb_pages = 702,
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 livre = Livre(
#       2     auteur = "Sébastien CHAZALLET",
#       3     nb_pages = 702,
#       4 )
#
# File ~/Documents/repositories/python_support/.venv/lib/python3.11/site-packages/pydantic/main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
#     257         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     258         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     259         stacklevel=2,
#     260     )
#
# ValidationError: 1 validation error for Livre
# titre
#   Field required [type=missing, input_value={'auteur': 'Sébastien CH...ALLET', 'nb_pages': 702}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing

# %%
Livre(
    auteur = 42,
    titre = "Python3, les fondamentaux du langage",
    nb_pages = 702,
)

# %%
livre = Livre(
    auteur="Sébastien CHAZALLET",
    titre="Python3, les fondamentaux du langage",
    nb_pages=702,
)
livre.auteur = "Autre auteur"

# %% [markdown]
# Coercition des données
# --

# %%
Livre.model_validate({
    "auteur": "Sébastien CHAZALLET",
    "titre": "Python3, les fondamentaux du langage",
    "nb_pages": 702,
})
# Out:
# Livre(auteur='Sébastien CHAZALLET', titre='Python3, les fondamentaux du langage', nb_pages=702)

# %%
Livre.model_validate(
    {
        "auteur": "Sébastien CHAZALLET",
        "titre": "Python3, les fondamentaux du langage",
        "nb_pages": 702.0,
    }
)
# Out:
# Livre(auteur='Sébastien CHAZALLET', titre='Python3, les fondamentaux du langage', nb_pages=702)

# %%
livre = Livre(
    auteur="Sébastien CHAZALLET",
    titre="Python3, les fondamentaux du langage",
    nb_pages=702.0,
)
print(livre)
# Out:
# auteur='Sébastien CHAZALLET' titre='Python3, les fondamentaux du langage' nb_pages=702

# %%
Livre.model_validate(
    {
        "auteur": "Sébastien CHAZALLET",
        "titre": "Python3, les fondamentaux du langage",
        "nb_pages": 702.0,
    },
    strict=True,
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 Livre.model_validate(
#       2     {
#       3         "auteur": "Sébastien CHAZALLET",
#       4         "titre": "Python3, les fondamentaux du langage",
#       5         "nb_pages": 702.0,
#       6     },
#       7     strict=True,
#       8 )
#
# File ~/Documents/repositories/python_support/.venv/lib/python3.11/site-packages/pydantic/main.py:705, in BaseModel.model_validate(cls, obj, strict, from_attributes, context, by_alias, by_name)
#     699 if by_alias is False and by_name is not True:
#     700     raise PydanticUserError(
#     701         'At least one of `by_alias` or `by_name` must be set to True.',
#     702         code='validate-by-alias-and-name-false',
#     703     )
# --> 705 return cls.__pydantic_validator__.validate_python(
#     706     obj, strict=strict, from_attributes=from_attributes, context=context, by_alias=by_alias, by_name=by_name
#     707 )
#
# ValidationError: 1 validation error for Livre
# nb_pages
#   Input should be a valid integer [type=int_type, input_value=702.0, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.11/v/int_type

# %%
Livre.model_validate_json(
    '{"auteur": "Sébastien CHAZALLET", "titre": "Python3, les fondamentaux du langage", "nb_pages": 702.0}',
    strict=True,
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 Livre.model_validate_json(
#       2     '{"auteur": "Sébastien CHAZALLET", "titre": "Python3, les fondamentaux du langage", "nb_pages": 702.0}',
#       3     strict=True,
#       4 )
#
# File ~/Documents/repositories/python_support/.venv/lib/python3.11/site-packages/pydantic/main.py:746, in BaseModel.model_validate_json(cls, json_data, strict, context, by_alias, by_name)
#     740 if by_alias is False and by_name is not True:
#     741     raise PydanticUserError(
#     742         'At least one of `by_alias` or `by_name` must be set to True.',
#     743         code='validate-by-alias-and-name-false',
#     744     )
# --> 746 return cls.__pydantic_validator__.validate_json(
#     747     json_data, strict=strict, context=context, by_alias=by_alias, by_name=by_name
#     748 )
#
# ValidationError: 1 validation error for Livre
# nb_pages
#   Input should be a valid integer [type=int_type, input_value=702.0, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.11/v/int_type

# %%
Livre.model_validate_json(
    '{"auteur": "Sébastien CHAZALLET", "titre": "Python3, les fondamentaux du langage", "nb_pages": 702.0}',
)
# Out:
# Livre(auteur='Sébastien CHAZALLET', titre='Python3, les fondamentaux du langage', nb_pages=702)

# %%
from datetime import date, datetime
from pydantic import Field

class Livre(BaseModel):
    auteur: str
    titre: str
    nb_pages: int | None = None
    date_parution: date  # Déclaré après une valeur optionnelle

# %%
Livre.model_validate(
    {
        "auteur": "Sébastien CHAZALLET",
        "titre": "Python3, les fondamentaux du langage",
        "date_parution": date(2023, 6, 1),
    }
)
# Out:
# Livre(auteur='Sébastien CHAZALLET', titre='Python3, les fondamentaux du langage', nb_pages=None, date_parution=datetime.date(2023, 6, 1))

# %%
Livre.model_validate(
    {
        "auteur": "Sébastien CHAZALLET",
        "titre": "Python3, les fondamentaux du langage",
        "date_parution": "2023-06-01",
    }
)
# Out:
# Livre(auteur='Sébastien CHAZALLET', titre='Python3, les fondamentaux du langage', nb_pages=None, date_parution=datetime.date(2023, 6, 1))

# %%
Livre.model_validate_json(
    '{"auteur": "Sébastien CHAZALLET", "titre": "Python3, les fondamentaux du langage", "date_parution": "2023-06-01"}'
)

# %%
class QuizzItem(BaseModel):
    question: str
    reponses: list[str] = Field(default_factory=list[str])

# %%
item_1 = QuizzItem(
    question = "Ceci est une question",
)

# %%
item_2 = QuizzItem(
    question = "Ceci est une autre question",
)

# %%
item_3 = QuizzItem(
    question = "Ceci est LA question",
    reponses = [
        "la réponse est évidente",
        "la réponse est cachée quelque part",
        "la réponse est ailleurs",
        "la réponse D",
    ]
)

# %%
class Quizz(BaseModel):
    items: list[QuizzItem]
    created: datetime = Field(default_factory=datetime.now)

# %%
quizz = Quizz(
    items = [item_1, item_2, item_3]
)

# %%
pprint(quizz)

# %%
pprint(quizz.model_dump())

# %%
pprint(Quizz.model_json_schema())

# %% [markdown]
# Lien avec dataclass
# --
#
# ### Convertion d'une dataclass

# %%
from dataclasses import dataclass, asdict

@dataclass(slots=True)
class DtLivre:
    auteur: str
    titre: str
    date_parution: date
    nb_pages: int | None = None
    

Livre.model_validate(
    asdict(
        DtLivre(
            auteur="Sébastien CHAZALLET",
            titre="Python3, les fondamentaux du langage",
            date_parution=date(2023, 6, 1),
            nb_pages=702.0,
        )
    )
)

# %% [markdown]
# ### Utilisation de dataclass du module pydantic

# %%
from pydantic.dataclasses import dataclass

# %%
@dataclass
class PyDtLivre:
    auteur: str
    titre: str
    date_parution: date
    nb_pages: int | None = None

# %%
PyDtLivre(
    auteur="Sébastien CHAZALLET",
    titre="Python3, les fondamentaux du langage",
    date_parution="2023-06-01",
    nb_pages=702.0,
)

# %%
PyDtLivre.model_validate(
    {
        "auteur": "Sébastien CHAZALLET",
        "titre": "Python3, les fondamentaux du langage",
        "date_parution": "2023-06-01",
        "nb_pages": 702.0,
    }
)

# %%
PyDtLivre(
    "Sébastien CHAZALLET",
    "Python3, les fondamentaux du langage",
    "2023-06-01",
    702,
)

# %%
livre = PyDtLivre(
    auteur="Sébastien CHAZALLET",
    titre="Python3, les fondamentaux du langage",
    date_parution="2023-06-01",
    nb_pages=702.0,
    editeur="ENI",
)

# %%
livre

# %%
livre.editeur

# %%
dir(livre)

# %%
pprint(livre.__dict__)

# %% [markdown]
# ---
